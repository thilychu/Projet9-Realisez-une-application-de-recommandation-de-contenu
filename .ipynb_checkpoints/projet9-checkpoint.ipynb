# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype  # Import the function

from tqdm import tqdm
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity, linear_kernel
from sklearn.preprocessing import StandardScaler

# %%
DATA_PATH = "D:/openclassroom/projet9/input/news-portal-user-interactions-by-globocom/"

# %%
NUM_EMBEDDINGS = 250
articles_metadata = pd.read_csv(DATA_PATH + "articles_metadata.csv")
articles_embeddings = pd.DataFrame(pd.read_pickle(DATA_PATH + "articles_embeddings.pickle"),columns=["embedding_" + str(i) for i in range(NUM_EMBEDDINGS)])
df_articles = pd.concat([articles_metadata,articles_embeddings],axis=1)
df_articles = df_articles.astype({"created_at_ts": "datetime64[ns]"})

# %%
df_articles.head()
# Out:
#    article_id  category_id              created_at_ts  publisher_id  \
# 0           0            0 1970-01-01 00:25:13.144419             0
# 1           1            1 1970-01-01 00:23:25.341936             0
# 2           2            1 1970-01-01 00:23:28.667706             0
# 3           3            1 1970-01-01 00:23:28.468313             0
# 4           4            1 1970-01-01 00:23:27.071171             0
#
#    words_count  embedding_0  embedding_1  embedding_2  embedding_3  \
# 0          168    -0.161183    -0.957233    -0.137944     0.050855
# 1          189    -0.523216    -0.974058     0.738608     0.155234
# 2          250    -0.619619    -0.972960    -0.207360    -0.128861
# 3          230    -0.740843    -0.975749     0.391698     0.641738
# 4          162    -0.279052    -0.972315     0.685374     0.113056
#
#    embedding_4  ...  embedding_240  embedding_241  embedding_242  \
# 0     0.830055  ...       0.321248       0.313999       0.636412
# ...

# %%
## Visualize Articles Categories distribution

# Group the DataFrame by 'category' and count the number of articles in each category
category_counts = articles_metadata['category_id'].value_counts()[0:50]

# Create a bar plot
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Article Categories')
plt.xlabel('Category')
plt.ylabel('Number of Articles')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
## Visualize Articles Word count distribution

# Group the DataFrame by 'category' and count the number of articles in each category
category_counts = articles_metadata['words_count']

# Create a histogram
plt.figure(figsize=(10, 6))
category_counts.plot(kind='hist', color='skyblue', bins=50)  # You can adjust the number of bins as needed
plt.title('Distribution of Article Word Counts')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
df_clicks = pd.concat(
    [
        pd.read_csv(
            click_file_path)
        for click_file_path in sorted(Path(DATA_PATH, "clicks/clicks").glob("clicks_hour_*.csv"))
    ],
    sort=False,
    ignore_index=True,
    verify_integrity=True,
)

df_clicks = df_clicks.astype(
    {"session_start": "datetime64[ns]", "click_timestamp": "datetime64[ns]"}
)

# %%
df_clicks.head()
# Out:
#   user_id        session_id              session_start session_size  \
# 0       0  1506825423271737 1970-01-01 00:25:06.825423            2
# 1       0  1506825423271737 1970-01-01 00:25:06.825423            2
# 2       1  1506825426267738 1970-01-01 00:25:06.825426            2
# 3       1  1506825426267738 1970-01-01 00:25:06.825426            2
# 4       2  1506825435299739 1970-01-01 00:25:06.825435            2
#
#   click_article_id               click_timestamp click_environment  \
# 0           157541 1970-01-01 00:25:06.826828020                 4
# 1            68866 1970-01-01 00:25:06.826858020                 4
# 2           235840 1970-01-01 00:25:06.827017951                 4
# 3            96663 1970-01-01 00:25:06.827047951                 4
# 4           119592 1970-01-01 00:25:06.827090575                 4
#
#   click_deviceGroup click_os click_country click_region click_referrer_type
# 0                 3       20             1           20                   2
# ...

# %% [markdown]
# ## Content-Based Filtering
# Le Content-Based Filtering (Filtrage basé sur le contenu en français) est une méthode de recommandation utilisée dans les systèmes de recommandation pour proposer des éléments similaires à un utilisateur en se basant sur les caractéristiques ou le contenu des éléments qu'il a déjà appréciés.
#
#     Extraction des caractéristiques des éléments : Tout d'abord, il est essentiel d'extraire des caractéristiques pertinentes des éléments à recommander.
#
#     Construction du profil de l'utilisateur : En suite on construit un profil utilisateur basé sur les interactions comme favoris, aimés ou consultés.
#
#     Calcul de la similarité : On calcule la similarité cosinus entre le profil de l'utilisateur et les caractéristiques des éléments disponibles.
#
#     Recommandations personnalisées : Les éléments qui présentent la plus grande similarité avec le profil de l'utilisateur sont alors recommandés. Plus la similarité est élevée, plus l'élément a de chances d'être recommandé.

# %% [markdown]
# **Modélisation des préférences de l'utilisateur**
#
# Le rating de l'utilisateur pour un article est défini comme la moyenne de tous les articles cliqués:
#
#     Rating(user,article)= #Clicks(user,article) / #Clicks(user)

# %%
def aggregate_articles(articles):
    return articles.groupby(lambda x: True).agg(
        {
            col: "mean"
            if is_numeric_dtype(articles.dtypes[col])
            else lambda x: x.mode()[0]
            for col in articles.columns
        }
    )


def get_user_interest(user_id, clicks, articles):
    all_article_ids = clicks.query("user_id == @user_id")["click_article_id"]
    interest = aggregate_articles(articles.query("article_id in @all_article_ids")).drop(["article_id"], axis=1)
    return interest

# %%
user_id = 100
interest = get_user_interest(user_id, df_clicks, df_articles)

# %%
interest
# Out:
#       category_id              created_at_ts  publisher_id  words_count  \
# True        340.4 1970-01-01 00:25:06.770125           0.0        194.2
#
#       embedding_0  embedding_1  embedding_2  embedding_3  embedding_4  \
# True    -0.495968    -0.970604      0.25876    -0.378692    -0.275372
#
#       embedding_5  ...  embedding_240  embedding_241  embedding_242  \
# True    -0.036043  ...      -0.344387      -0.031984      -0.550287
#
#       embedding_243  embedding_244  embedding_245  embedding_246  \
# True       0.353212       0.003794      -0.139346       0.260136
#
#       embedding_247  embedding_248  embedding_249
# True       0.235911       0.261088       0.243127
#
# [1 rows x 254 columns]

# %% [markdown]
# **Calculer la similarité cosinus (cosine_similarity) entre le profil utilisateur et les articles**
#
# Les caractéristiques avec des échelles différentes peuvent avoir un impact disproportionné sur la mesure de similarité. En normalisant les données, on se assure que toutes les caractéristiques ont la même importance dans le calcul de la similarité

# %%
def normalize_data(interest, articles):
    articles_copy = articles.copy()
    articles_copy["created_at_ts"] = articles["created_at_ts"].apply(lambda x: x.value)
    articles_copy = articles_copy.drop(["article_id"], axis=1, errors="ignore")
    interest_copy = interest.copy()
    interest_copy["created_at_ts"] = interest_copy["created_at_ts"].apply(lambda x: x.value)
    # Créez le scaler et normalisez le DataFrame
    scaler = StandardScaler()
    articles_std = scaler.fit_transform(articles_copy)
    interest_std = scaler.transform(interest_copy)
    
    return interest_std, articles_std

# %%
def get_closest_articles(user_id, clicks, articles, n=10):
    
    interest = get_user_interest(user_id, clicks, articles)
    interest_std, articles_std = normalize_data(interest, articles)
    articles["similarity"] = cosine_similarity(interest_std, articles_std)[0]
    closest_articles = articles.sort_values("similarity", ascending=False).iloc[:n]
    
    return closest_articles

# %%
df_articles
# Out:
#         article_id  category_id              created_at_ts  publisher_id  \
# 0                0            0 1970-01-01 00:25:13.144419             0
# 1                1            1 1970-01-01 00:23:25.341936             0
# 2                2            1 1970-01-01 00:23:28.667706             0
# 3                3            1 1970-01-01 00:23:28.468313             0
# 4                4            1 1970-01-01 00:23:27.071171             0
# ...            ...          ...                        ...           ...
# 364042      364042          460 1970-01-01 00:23:54.034118             0
# 364043      364043          460 1970-01-01 00:23:54.148472             0
# 364044      364044          460 1970-01-01 00:24:17.974279             0
# 364045      364045          460 1970-01-01 00:25:15.964737             0
# 364046      364046          460 1970-01-01 00:25:05.811330             0
#
#         words_count  embedding_0  embedding_1  embedding_2  embedding_3  \
# ...

# %%
closest_articles = get_closest_articles(12, df_clicks, df_articles)
closest_articles
# Out:
#         article_id  category_id              created_at_ts  publisher_id  \
# 282957      282957          412 1970-01-01 00:25:01.535560             0
# 284482      284482          412 1970-01-01 00:25:04.106264             0
# 345462      345462          440 1970-01-01 00:25:12.895631             0
# 345082      345082          440 1970-01-01 00:25:13.333642             0
# 345895      345895          440 1970-01-01 00:25:14.014171             0
# 284180      284180          412 1970-01-01 00:25:04.975205             0
# 286311      286311          412 1970-01-01 00:25:05.973662             0
# 284198      284198          412 1970-01-01 00:25:02.949695             0
# 283544      283544          412 1970-01-01 00:25:05.548416             0
# 345826      345826          440 1970-01-01 00:25:13.400459             0
#
#         words_count  embedding_0  embedding_1  embedding_2  embedding_3  \
# 282957          194    -0.606592    -0.976242    -0.467239    -0.760416
# ...

# %%
df_articles
# Out:
#         article_id  category_id              created_at_ts  publisher_id  \
# 0                0            0 1970-01-01 00:25:13.144419             0
# 1                1            1 1970-01-01 00:23:25.341936             0
# 2                2            1 1970-01-01 00:23:28.667706             0
# 3                3            1 1970-01-01 00:23:28.468313             0
# 4                4            1 1970-01-01 00:23:27.071171             0
# ...            ...          ...                        ...           ...
# 364042      364042          460 1970-01-01 00:23:54.034118             0
# 364043      364043          460 1970-01-01 00:23:54.148472             0
# 364044      364044          460 1970-01-01 00:24:17.974279             0
# 364045      364045          460 1970-01-01 00:25:15.964737             0
# 364046      364046          460 1970-01-01 00:25:05.811330             0
#
#         words_count  embedding_0  embedding_1  embedding_2  embedding_3  \
# ...

# %% [markdown]
# ## Collaborative Filtering
#
# Le Collaborative Filtering est de recommander des éléments à un utilisateur en se basant sur les préférences ou le comportement d'autres utilisateurs similaires.
#
# Il existe deux principales approches de filtrage collaboratif :
#
# 1. Filtrage collaboratif basé sur les utilisateurs :
#
# Dans cette approche, les recommandations sont générées en identifiant des utilisateurs similaires à l'utilisateur cible. La similarité peut être calculée en fonction des notations ou des interactions passées avec les éléments.
# Une fois les utilisateurs similaires identifiés, les éléments qui ont été appréciés par ces utilisateurs et qui n'ont pas encore été appréciés par l'utilisateur cible sont recommandés à ce dernier.
# Par exemple, si l'utilisateur A et l'utilisateur B ont des préférences similaires pour les films et que l'utilisateur A a aimé un film que l'utilisateur B n'a pas encore vu, le système recommandera ce film à l'utilisateur B.
#
# 2. Filtrage collaboratif basé sur les éléments :
#
# Dans cette approche, les recommandations sont générées en se basant sur les caractéristiques des éléments et en trouvant des éléments similaires à ceux que l'utilisateur a déjà aimés.
# Les caractéristiques des éléments peuvent inclure des genres, des mots-clés, des catégories, etc. Par exemple, pour les films, les caractéristiques peuvent inclure le genre, le réalisateur, les acteurs, etc.
# Lorsqu'un utilisateur a aimé un élément, le système recommandera d'autres éléments similaires en fonction de leurs caractéristiques.
# Par exemple, si un utilisateur a aimé un film de science-fiction, le système recommandera d'autres films de science-fiction.
# Le filtrage collaboratif peut être mis en œuvre de différentes manières, notamment avec des méthodes de calcul de similarité, telles que la similarité cosinus ou la distance euclidienne. De plus, il peut être utilisé avec des données explicites (notations ou évaluations numériques données par les utilisateurs) ou des données implicites (comme les clics, les vues, les achats, etc.).
